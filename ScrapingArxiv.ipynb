# %%
"""
This code is scrapping Arxiv for research papers by keywords

"""

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
topics = pd.read_csv('TopicsLists/PhysicsTopics.csv')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\AhmedHassanOsmanIbra\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\AHMEDH~1\AppData\Local\Temp/ipykernel_28668/3192829946.py", line 1, in <module>
#     topics = pd.read_csv('PhysicsTopics.csv')
#   File "c:\Users\AhmedHassanOsmanIbra\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\AhmedHassanOsmanIbra\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
# ...

# %%
df = pd.DataFrame({'links': list(),'topic':list()})
for j in topics['Topics']:
    for i in range(0,10000,200):
        try:
            search = f"https://arxiv.org/search/?searchtype=all&query={j}&abstracts=show&size=200&order=&start={i}"
            response = requests.get(search)
            soup = BeautifulSoup(response.content, 'html.parser')
            x = soup.find_all('a')
            for i in x:
                try:
                    if 'abs' in i['href'] and 'search' not in i['href'] and i['href'] not in df['links']:
                        df.loc[len(df.index)] = [i['href'], j]
                except:
                    continue
        except:
            continue
    df.to_csv('arxivLinksPhysics.csv',index=False)
    print(j)
# Out:
# physics
# mechanics
# materials science
# nuclear physics
# particle physics
# thermodynamics
# Glossary of chemistry terms
# Glossary of astronomy
# Glossary of areas of mathematics
# Glossary of engineering
# Physics
# Index
# Outline
# History
# timeline
# Acoustics
# Astrophysics
# Atomic physics
# Biophysics
# Classical physics
# Electromagnetism
# Geophysics
# Mechanics
# Modern physics
# Nuclear physics
# Optics
# Thermodynamics
# Physicist
# list
# List of physics awards
# List of journals
# List of unsolved problems
# Physics portal
# Category
# edit
# ab initio
# Abbe number
# absolute electrode potential
# electrochemistry
# absolute humidity
# absolute motion
# absolute pressure
# absolute scale
# measurement
# absolute zero
# ideal gas
# absorption spectroscopy
# absorption spectrum
# absorptivity
# accelerating expansion of the universe
# expansion
# universe
# acceleration
# acceleration due to gravity
# accelerometer
# acoustics
# adhesion
# adiabatic cooling
# ...

# %%
import numpy as np

# %%
Links = pd.read_csv('arxivLinksPhysicsNew.csv')

# %%
Links['links'][0][:8]+'export.'+Links['links'][0][8:]
# Out:
# 'https://export.arxiv.org/abs/2206.00647'

# %%
for i in range(len(Links['links'])):
    try:
        if pd.isna(Links['abstract'][i]):
            link = Links['links'][i][:8]+'export.'+Links['links'][i][8:]
            Research = requests.get(link)
            researchSoup = BeautifulSoup(Research.content, 'html.parser')
            y = researchSoup.find('blockquote', class_="abstract mathjax")
            links = researchSoup.find_all('a')
            if 'Abstract' in y.text:
                Links['abstract'][i] = y.text[11:].strip()
                for j in links:
                    try:
                        if 'doi' in j['href']:
                            Links['DOI'][i] = j['href']
                    except:
                        continue
        else:
            continue
        if i % 100 == 0:
            Links.to_csv('ArxivMainData.csv',index=False)
            print(i)
    except:
        continue
# Out:
# 110800
# 110900
# 111000
# 111100
# 111200
# 111300
# 111400
# 111500
# 111600
# 111700
# 123800
# 123900
# 124000
# 124100
# 124200
# 124300
# 124400
# 124500
# 124600
# 147300
# 147400
# 147500
# 147600
# 147700
# 147800
# 147900
# 148000
# 148100
# 148200
# 148300
# 148400
# 148500
# 148600
# 148700
# 148800
# 148900
# 149000
# 149100
# 149200
# 149300
# 149400
# 149500
# 149600
# 149700
# 149800
# 149900
# 150000
# 150100
# 150200
# 150300
# 150400
# 150500
# 150600
# 150700
# 150800
# 150900
# 151000
# 151100
# 151200
# 151300
# 151400
# 151500
# 151600
# 151700
# 151800
# 151900
# 152000
# 152100
# 152200
# 152300
# 152400
# 159200
# 159300
# 159400
# 159500
# 159600
# 159700
# 159800
# 159900
# 160000
# 160100
# 160400
# 160500
# 160600
# 160700
# 160800
# 160900
# 161000
# 161100
# 161200
# 161300
# 161400
# 161500
# 161600
# 161700
# 161800
# 161900
# 162000
# 162100
# 162200
# 162300
# 162400
# 162500
# 162600
# 162700
# 162800
# 162900
# 163000
# 163100
# 163200
# 163300
# ...

# %%
Links
# Out:
#                                          links            topic  \
# 0             https://arxiv.org/abs/2206.00647          physics
# 1             https://arxiv.org/abs/2206.00639          physics
# 2             https://arxiv.org/abs/2206.00634          physics
# 3             https://arxiv.org/abs/2206.00602          physics
# 4             https://arxiv.org/abs/2206.00597          physics
# ...                                        ...              ...
# 247684    https://arxiv.org/abs/hep-th/9412002  absolute motion
# 247685  https://arxiv.org/abs/astro-ph/9407075  absolute motion
# 247686  https://arxiv.org/abs/astro-ph/9407003  absolute motion
# 247687    https://arxiv.org/abs/hep-th/9404059  absolute motion
# 247688  https://arxiv.org/abs/astro-ph/9303017  absolute motion
#
#                                                  abstract  DOI
# 0       Conversion cathode materials are gaining inter...  NaN
# 1       For a single fermionic field, an interpretatio...  NaN
# ...
